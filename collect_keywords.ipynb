# %%
from translate import (
    ORIGINAL_SRT,
    load_srt,
    make_dict,
    items_per_time,
    translate_text,
    origin_lang,
    target_lang
)
from pprint import pprint
from itertools import islice
from config import headers, proxies, api_base
import requests
import time
import json
import re
from tqdm import tqdm

model_to_use = "gpt-4o"

def dict_chunks(dictionary, n):
    items = iter(dictionary.items())
    return iter(lambda: dict(islice(items, n)), {})

def find_last_json_list(text):
    json_matches = re.findall(r'\[.*?\]', text, re.DOTALL)
    
    if json_matches:
        return eval(json_matches[-1])
    else:
        return None

def is_reply_valid(text, t_text):
    try:
        trans = find_last_json_list(t_text)
        assert isinstance(trans, list), "Trans is not a dict!"
        assert trans, "Trans is None!"
    except SyntaxError:
        print(f"Error: unable to eval the output of AI: {t_text}")
        return False
    except AssertionError:
        print(f"Error: Not a list! {type(trans)=}")
        return False
    except json.decoder.JSONDecodeError:
        print(f"Error: unable to eval the output of AI: {t_text}")
        return False
    else:
        return True

def get_keyword(text: str) -> str:
    max_retries = 5
    retries = 0
    while retries < max_retries:
        try:
            max_tokens = 2000 if "qwen" in model_to_use else 3000
            data = {
                "model": model_to_use,
                "response_format": {"type": "json_object"},
                "messages": [
                    {
                        "role": "system",
                        "content": EXTRACTION_PROMPT,
                    },
                    {
                        "role": "user",
                        "content": text,
                    },
                ],
                "max_tokens": max_tokens,
                # 'temperature': 0.5,
            }
            completion = {}
            response = requests.post(
                f"{api_base}/chat/completions",
                headers=headers,
                data=json.dumps(data),
                proxies=proxies,
                timeout=60,
            )
            completion = response.json()
            assert response.status_code == 200
            t_text = completion["choices"][0]["message"]["content"]

            if is_reply_valid(text, t_text):
                return t_text
            else:
                retries += 1
                print()
                print(text)
                print(t_text)
                print(f"Invalid translation format. Retrying ({retries}/{max_retries})")
                time.sleep(3)

        except Exception as e:
            sleep_time = 10
            print()
            print(completion)
            print(
                e,
                f"will sleep {sleep_time} seconds, Retrying ({retries}/{max_retries})",
            )
            time.sleep(sleep_time)
            retries += 1

    print(
        f"Unable to get a valid translation after {max_retries} retries. Returning the original text."
    )
    return text

EXTRACTION_PROMPT = "You are a professional translation coordinator. You are responsible for extracting proper nouns, technical terms, and other items that need to be standardized in translation from foreign language subtitles." \
    "The subtitles will be provided in JSON dictionary format. Please reply with a JSON list of all foreign language keywords. You may first analyze and think through step by step to confirm whether the keywords are necessary, and then output the final JSON list."
TRANSLATE_PROMPT = "你是一个专业的术语关键词翻译，请将{}的术语翻译为{}，并且用json字典输出，键和值分别是原文和翻译。"

def main():
    subs = load_srt(ORIGINAL_SRT)
    feed_dict = make_dict(subs)

    keywords = []
    for chunk in tqdm(dict_chunks(feed_dict, items_per_time)):
        no_timestamp = {k: v[1] for k, v in chunk.items()}
        print(no_timestamp)
        current = get_keyword(json.dumps(no_timestamp).lower())
        # print(f"Reply: {current}")
        current = find_last_json_list(current)
        if current is None:
            continue
        elif not isinstance(current, list):
            print("Not a list, continuing. . .")
            continue
        keywords += current

    print(keywords)
    keywords = list(set(keywords))
    all_kws = get_keyword(json.dumps(keywords))
    all_kws = find_last_json_list(all_kws)

    print(all_kws)

    source_text = json.dumps(all_kws)
    translation = translate_text(source_text, TRANSLATE_PROMPT.format(origin_lang, target_lang), False)
    print(translation)

main()
# Out:
# f:\ProgramData\Miniconda3\lib\site-packages\requests\__init__.py:109: RequestsDependencyWarning: urllib3 (2.1.0) or chardet (5.2.0)/charset_normalizer (2.1.1) doesn't match a supported version!
#   warnings.warn(
# 0it [00:00, ?it/s]
# {'1': "Just when you're trying to figure out the release date for the final season of Stranger Things,", '2': 'one of these banners pops up at the top of Wikipedia.', '3': "Please don't scroll past this one-minute read.", '4': "It's a little awkward to ask, but this Thursday we need your help.", '5': 'It will soon be too late to help us in our fundraiser.', '6': 'Wikipedia is not for sale.', '7': "We humbly ask you to defend Wikipedia's independence.", '8': "98% of our readers don't donate.", '9': 'They simply look the other way.', '10': 'If you donate just $3, you would help keep Wikipedia thriving for years.', '11': "That's right, the price of a cup of coffee is all we need.", '12': 'Please donate now. It really matters.', '13': 'These banners exist in all kinds of languages.', '14': 'Wikipedia is asking for money all over the planet.', '15': 'Some of these wordings sound almost desperate.', '16': 'Like Wikipedia is on the brink of collapse.', '17': 'Like one of the most amazing parts of the internet is about to shut down', '18': 'and urgently needs your cash injection to stay alive.', '19': 'But is that really true? What if Wikipedia was actually pretty rich?', '20': 'Wikipedia was founded on January 15, 2001 by entrepreneur Jimmy Wales and philosopher Larry Sanger.'}
# 1it [00:01,  1.82s/it]
# {'21': 'The original idea was to create an online encyclopedia with entries written by experts.', '22': 'But the founders launched and tested an early version of the platform where anyone could', '23': 'add or edit articles.', '24': 'That concept turned out to be a massive hit.', '25': 'Today, Wikipedia is one of the most visited websites in the world.', '26': 'In summer of 2024, it racked up about 6.7 billion visits per month.', '27': 'The platform has more than 61 million articles with over 6.8 million pages in English alone.', '28': 'Since its inception, Wikipedia has never done ads.', '29': 'The platform has mostly been funded by donations.', '30': 'But these donations do not go to the millions of wiki\neditors who tirelessly write and edit the countless articles.', '31': 'They all do it for free.', '32': 'The money goes to the Wikimedia Foundation, or WMF for short.', '33': "That's the non-profit behind Wikipedia.", '34': 'In the beginning, the foundation mainly focused on\nkeeping the site running and paying a few employees.', '35': 'Occasionally, some wiki editors were also given financial support for specific projects.', '36': 'Then in 2005, the foundation launched its first ever fundraising campaign.', '37': 'That was also the first time donation banners were used on the site.', '38': 'The initial goal was to raise $75,000.', '39': 'It was surpassed by almost 20k.', '40': 'Just a few months later, the next fundraising goal was set at $200,000.'}
# 2it [00:03,  1.85s/it]
# {'41': 'And it was quickly met.', '42': 'The campaigns became more frequent over the years.', '43': 'In 2010, Jimmy Wales was featured on many of the donation banners.', '44': 'His personal appeal was meant to encourage more people to give.', '45': 'His face was suddenly everywhere on the platform.', '46': 'As a result, whales became a meme.', '47': 'Either way Wikipedia started growing so fast that\nWikimedia genuinely needed more money every year', '48': 'In 2013 the then director of the foundation estimated\ntheir budget needs to be around million per year', '49': 'He said that would cover the operating costs for the website and allow them to keep pushing', '50': "Wikimedia's mission through other projects and initiatives.", '51': 'And over the last 10 years, Wikipedia has still\nbeen frequently asking for money around the globe.', '52': 'Some of these banners sound like Wikipedia and its independence were in danger.', '53': 'Like the site could go offline at any moment.', '54': 'But is that true?', '55': "Holzcan is the sponsor of today's video and\nwould definitely deserve its own Wikipedia page.", '56': 'The bio section would probably say that the Vienna-based designers are known for designing', '57': 'accessories that are sleek, stylish and sustainable.', '58': 'They started out creating unique watches made from natural elements like wood and stone,', '59': 'like this one or that one.', '60': 'But that was just the beginning.'}
# 3it [00:05,  1.68s/it]
# {'61': 'Today, Holzkern also offers a range of accessories from jewelry to sunglasses and handbags,', '62': 'all crafted with an attention to natural detail and the environment.', '63': 'Through their small product line and their high-quality standards, they ensure a great', '64': 'longevity of their products.', '65': 'What we really like is that each Holzkern piece is one-of-a-kind, thanks to the unique', '66': 'grain and marbling of the organic materials.', '67': 'Plus the wood used is either FSC certified or upcycled, and the company actively supports', '68': 'reforestation projects. Check out Holscan and use the code FERNHK for an exclusive 10% off', '69': "on all Holscan products. Let's look at India for a second. Two-thirds of the country's population", '70': "live in poverty, surviving on less than $2 a day. Yet in 2020, Wikimedia's donation campaigns were", '71': "asking for 150 Indian rupees. That's almost $1.80. The 2020 campaign urged people to defend", '72': "Wikipedia's independence, users were asked to help keep Wikipedia online and growing.", '73': 'The banners made it sound like Wikipedia really depended on these donations.', '74': 'During the pandemic, a regular donor in the US was contacted by the Wikimedia Foundation via email.', '75': 'They asked him to consider including the foundation in his will. The mail even included', '76': 'a direct link to a service that lets you draft a will in just 20 minutes.', '77': 'Bitte scrollen Sie nicht weg.', '78': 'Viele Leute geben nichts und schauen einfach weg.', '79': 'Wir brauchen Geld von Ihnen.', '80': 'This is Andreas Kolbe.'}
# 4it [00:07,  1.94s/it]
# {'81': 'He has been a volunteer editor at Wikipedia for over 15 years and is the former chief', '82': 'editor of the Signpost, an online newspaper within the Wikipedia movement.', '83': "He has been criticizing the Wikimedia Foundation's fundraising campaigns for years, especially", '84': 'wording suggesting that', '85': 'Das Wikipedia leidet an akutem Geldmangel', '86': 'und jetzt dringend Spenden eingefahren werden müssen, damit die Webseite weiterhin bestehen kann.', '87': 'That may have been true 20 years ago.', '88': 'but it is far from accurate today. The Wikimedia Foundation is not struggling at all. In fact,', '89': 'it doing better than ever Since its founding the revenue has constantly\nbeen growing', '90': 'During the fiscal year of 2022/2023 the\nfoundation raised roughly 165 million from over 13 million donations', '91': ' The money comes from all\nover the world but mostly from North America', '92': 'and Europe. At the end of that same period, Wikimedia had net assets worth almost 255 million', '93': 'dollars, primarily in cash and investments like corporate bonds and treasury securities. On top', '94': "On top of that, there's another $120 million in the so-called Wikimedia Endowment Fund,", '95': 'which is meant to ensure the access to free knowledge for future generations.', '96': 'But right now, those are just more investments, like stock funds, aimed at generating profits.', '97': "Die sagen quasi, it's awkward to ask. Und es ist überhaupt nicht peinlich.", '98': ' Wenn ich so viele Millionen in der Bank habe, dann ist es nicht peinlich, es ist unverschämt.', '99': 'Only a fraction of the donations are actually used to keep the site running.', '100': 'The foundation already has enough money to maintain the servers for well over 100 years.'}
# 5it [00:10,  2.38s/it]
# {'101': "If you invest some time to scroll through the website of the Wikimedia Foundation, you'll", '102': "quickly see how well they're doing and where exactly the money goes.", '103': 'But the site currently only gets around 400,000 visits per month, compared to the 7 billion', '104': 'monthly visits on Wikipedia.', '105': 'Whoever reads those dramatic banners and decides to throw in a couple of bucks will most likely', '106': 'do so without digging deeper into the organization and getting the full picture.', '107': "The contributions meant to help quote-unquote defend Wikipedia's independence mostly go", '108': 'to the 700 staff and contractors.', '109': 'In 2023, the foundation spent over $100 million on salaries and benefits.', '110': '$3.1 million went to the hosting of Wikipedia and its sister projects.', '111': 'Many of these employees do not work in IT.', '112': 'Their job is not to keep the website running smoothly.', '113': 'They work in marketing, administration and finance.', '114': 'To keep those donation campaigns running strong, the foundation employs a bunch of fundraising', '115': 'experts who specialize in exactly that.', '116': 'The foundation holds events and conferences all over the world.', '117': 'Money is spent on lobbying efforts.', '118': 'In 2023 alone, they also handed out 24 million dollars in awards and grants.', '119': 'Some of the money went to other organizations that\nare not part of Wikimedia but share similar goals.', '120': 'Durch das ganze Geld, was aber reingekommen ist, haben sich natürlich die Vorstellungen,'}
# 6it [00:11,  1.99s/it]
# {'121': 'was eigentlich die Mission der Wikimedia Foundation sein sollte, ganz rabiat verändert.', '122': 'Die Wikimedia Foundation\nmöchte jetzt viel mehr sein als einfach nur das,', '123': 'was sie\nsich damals vorgestellt hat.', '124': 'Today the WMF has little in common with the neatly defined project from the early 2000s.', '125': 'It now runs additional projects like the media archive Wikimedia Commons, Wikibooks', '126': 'and even a species directory.', '127': 'There are also regional chapters like Wikimedia Mexico that focus on expanding articles in', '128': 'Spanish covering area-specific content.', '129': 'In 2021, the foundation launched a for-profit company called Wikimedia Enterprise.', '130': "The goal is to give big tech companies easier access to Wikipedia content, whether it's", '131': 'through infoboxes like these or through voice assistants like\nAlexa and Siri', '132': 'Wikimedia Enterprise is set to become a major\nnew revenue stream for the foundation', '133': 'We reached out to the Wikimedia Foundation for\ncomment when first reporting on the subject in 2022.', '134': 'We asked them why some of their campaigns have been so desperate in tone. That was a main', '135': "area of criticism at the time. The foundation didn't really give us a clear answer on that one.", '136': "However, they did emphasize that the WMF's reserve would only cover 16 months of operating costs for", '137': 'for Wikipedia and its sister projects.', '138': "We've already broken down what those operating expenses look like earlier in this video.", '139': "The foundation also stressed that not everyone can afford to donate and that that's okay.", '140': 'Regarding the campaigns in India, they said many Indians use the encyclopedia and they'}
# 7it [00:14,  2.04s/it]
# {'141': 'just wanted to create opportunities for those who are willing and able to give.', '142': 'The current fundraising banners used in India also show that Wikipedia has lowered their', '143': 'suggested donation from 150 to 25 Indian rupees.', '144': "The WMF added that they're constantly working to improve their fundraising effort and that", '145': 'they are in close touch with volunteers and community members.', '146': "Obviously, it's totally fine to financially support Wikipedia.", '147': "It's one of the best things on the internet.", '148': "But it's not like the platform is going offline tomorrow if you do not donate today.", '149': "It'll most likely still be around in 10 or 20 years.", '150': 'Money-wise, the foundation is pretty well set for the future.', '151': "And that's not a bad thing at all.", '152': 'Wikimedia is a donation-funded foundation competing with services of major tech companies', '153': 'like Meta, Apple, and Amazon.', '154': "And while hundreds of millions of dollars in assets may sound like a lot, it's peanuts", '155': 'compared to Google and the rest.', '156': 'Neither is it a bad thing to want to expand and start new projects.', '157': 'We ourselves are regularly drawing on Wikimedia Commons for our videos.', '158': 'But why not be upfront about it?', '159': 'Why push so hard for donations, especially in developing countries like India?', '160': "Why pretend the website's independence is at risk?"}
# 8it [00:16,  2.03s/it]
# {'161': 'Is Wikipedia really considering running commercial ads?', '162': 'Or is that just clumsy marketing and emotional campaigning?', '163': 'Some calls for donation asked people to donate in support of the volunteer editors.', '164': 'In several Wikimedia forums, editors have expressed\ndisappointment with these kinds of actions.', '165': 'Some of them feel taken advantage of.', '166': 'In 2023, Wikimedia did a survey among volunteer editors to ask them about their opinion', '167': 'on the last fundraising campaign.', '168': 'Almost all participants agreed.', '169': 'The whiny parts of those donation banners were misleading and inappropriate.', '170': 'Wikipedia founder Jimmy Wales joined the discussion that followed.', '171': 'It looks like Wikimedia has heard the message.', '172': 'The foundation has started to actively collaborate\nwith its community to co-create fundraising campaigns.', '173': 'They are currently running limited pre-tests for English banners', '174': 'and are considering suggestions from volunteers.', '175': 'We hope that Wikimedia will keep listening to that feedback and find an appropriate language', '176': 'for their global fundraising campaigns.', '177': "Because in the end, it's really the passion and support of all those volunteer editors", '178': 'that make Wikipedia so great and worth supporting.'}
# 9it [00:18,  2.07s/it]
# ['stranger things', 'wikipedia', 'jimmy wales', 'larry sanger', 'january 15, 2001', 'wikipedia', 'wiki', 'wikimedia foundation', 'wmf', 'Jimmy Wales', 'Wikipedia', 'Wikimedia', 'Holzcan', 'Vienna', 'Holzkern', 'FSC', 'reforestation', 'Holscan', 'FernHK', 'India', 'Wikipedia', 'Wikimedia', '2020', 'Indian Rupees', 'US', 'Wikimedia Foundation', 'Andreas Kolbe', 'wikipedia', 'signpost', 'wikimedia foundation', 'das wikipedia leidet an akutem geldmangel', 'wikimedia endowment fund', 'north america', 'europe', 'treasury securities', 'corporate bonds', 'cash', 'dollars', 'millionen', 'Wikimedia Foundation', 'Wikipedia', 'Wikimedia Foundation', 'Wikimedia Commons', 'Wikibooks', 'Wikimedia Mexico', 'Wikimedia Enterprise', 'Wikipedia', 'Alexa', 'Siri', 'WMF', 'Wikipedia', 'Indian Rupees', 'WMF', 'Wikimedia', 'Meta', 'Apple', 'Amazon', 'Google', 'Wikimedia Commons', 'India', 'Wikipedia', 'commercial ads', 'Wikimedia', 'forums', 'volunteer editors', '2023', 'survey', 'fundraising campaign', 'donation banners', 'Wikipedia founder', 'Jimmy Wales', 'foundation', 'English banners', 'global fundraising campaigns']
# ['Vienna', 'Wikipedia', 'Jimmy Wales', 'FernHK', 'wikimedia endowment fund', 'Meta', 'Holzkern', 'Alexa', 'Wikimedia Enterprise', 'FSC', 'WMF', 'Holscan', 'Holzcan', 'Andreas Kolbe', 'Apple', 'Google', 'English banners', 'Larry Sanger', 'signpost', 'January 15, 2001', 'Wiki', 'Wikibooks', 'Wikimedia', 'Wikimedia Mexico', 'India', 'Wikimedia Foundation', 'Stranger Things', 'Siri', 'Indian Rupees', 'North America', 'Europe', 'Wikimedia Commons']
# [
#   {
#     "Vienna": "维也纳"
#   },
#   {
#     "Wikipedia": "维基百科"
#   },
#   {
#     "Jimmy Wales": "吉米·威尔士"
#   },
#   {
#     "FernHK": "FernHK"
#   },
#   {
#     "wikimedia endowment fund": "维基媒体捐赠基金"
#   },
#   {
#     "Meta": "Meta"
#   },
#   {
#     "Holzkern": "Holzkern"
#   },
#   {
#     "Alexa": "Alexa"
#   },
#   {
#     "Wikimedia Enterprise": "维基媒体企业"
#   },
#   {
#     "FSC": "FSC"
#   },
#   {
#     "WMF": "维基媒体基金会"
#   },
#   {
#     "Holscan": "Holscan"
#   },
#   {
#     "Holzcan": "Holzcan"
#   },
#   {
#     "Andreas Kolbe": "安德烈亚斯·科尔贝"
#   },
#   {
#     "Apple": "苹果"
#   },
#   {
#     "Google": "谷歌"
#   },
#   {
#     "English banners": "英文横幅"
#   },
#   {
#     "Larry Sanger": "拉里·桑格"
#   },
#   {
#     "signpost": "通讯"
#   },
#   {
#     "January 15, 2001": "2001年1月15日"
#   },
#   {
#     "Wiki": "Wiki"
#   },
#   {
#     "Wikibooks": "维基教科书"
#   },
#   {
#     "Wikimedia": "维基媒体"
#   },
#   {
#     "Wikimedia Mexico": "墨西哥维基媒体"
#   },
#   {
#     "India": "印度"
#   },
#   {
#     "Wikimedia Foundation": "维基媒体基金会"
#   },
#   {
#     "Stranger Things": "怪奇物语"
#   },
#   {
#     "Siri": "Siri"
#   },
#   {
#     "Indian Rupees": "印度卢比"
#   },
#   {
#     "North America": "北美洲"
#   },
#   {
#     "Europe": "欧洲"
#   },
#   {
#     "Wikimedia Commons": "维基共享资源"
#   }
# ]

# %%
x = {'Alexa': 'Alexa',
 'Andreas Kolbe': '安德烈亚斯·科尔贝',
 'Europe': '欧洲',
 'FSC': 'FSC',
 'FernHK': 'FernHK',
 'Google': '谷歌',
 'Indian Rupees': '印度卢比',
 'Stranger Things': '怪奇物语',
 'WMF': '维基媒体基金会',
 'Wikibooks': '维基教科书',
 'Wikimedia': '维基媒体',
 'Wikimedia Commons': '维基共享资源',
 'Wikimedia Enterprise': '维基媒体企业',
 'Wikimedia Foundation': '维基媒体基金会',
 'Wikimedia Mexico': '墨西哥维基媒体',
 'Wikipedia': '维基百科',
 'wikimedia endowment fund': '维基媒体捐赠基金'}

r = ""

for k, v in x.items():

    r += f"{k} --> {v}, "

r = r.strip(", ")

print(r)
# Out:
# Alexa --> Alexa, Andreas Kolbe --> 安德烈亚斯·科尔贝, Europe --> 欧洲, FSC --> FSC, FernHK --> FernHK, Google --> 谷歌, Indian Rupees --> 印度卢比, Stranger Things --> 怪奇物语, WMF --> 维基媒体基金会, Wikibooks --> 维基教科书, Wikimedia --> 维基媒体, Wikimedia Commons --> 维基共享资源, Wikimedia Enterprise --> 维基媒体企业, Wikimedia Foundation --> 维基媒体基金会, Wikimedia Mexico --> 墨西哥维基媒体, Wikipedia --> 维基百科, wikimedia endowment fund --> 维基媒体捐赠基金
